# %%
# !pip install yfinance pandas gym stable-baselines3[extra] tensorflow
# Out:
# ^C
# Requirement already satisfied: yfinance in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (0.2.33)
# Requirement already satisfied: pandas in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (2.1.4)
# Requirement already satisfied: gym in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (0.26.2)
# Requirement already satisfied: tensorflow in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (2.15.0)
# Requirement already satisfied: stable-baselines3[extra] in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (2.2.1)
# Requirement already satisfied: numpy>=1.16.5 in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from yfinance) (1.26.3)
# Requirement already satisfied: requests>=2.31 in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from yfinance) (5.0.0)
# Requirement already satisfied: appdirs>=1.4.4 in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from yfinance) (2023.3.post1)
# Requirement already satisfied: frozendict>=2.3.4 in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from yfinance) (2.4.0)
# Requirement already satisfied: peewee>=3.16.2 in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from yfinance) (3.17.0)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from yfinance) (4.12.2)
# Requirement already satisfied: html5lib>=1.1 in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from pandas) (2023.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from gym) (3.0.0)
# Requirement already satisfied: gym-notices>=0.0.4 in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from gym) (0.0.8)
# Requirement already satisfied: gymnasium<0.30,>=0.28.1 in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from stable-baselines3[extra]) (0.29.1)
# Requirement already satisfied: torch>=1.13 in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from stable-baselines3[extra]) (2.1.2)
# Requirement already satisfied: matplotlib in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from stable-baselines3[extra]) (3.8.2)
# Requirement already satisfied: opencv-python in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from stable-baselines3[extra]) (4.9.0.80)
# Requirement already satisfied: pygame in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from stable-baselines3[extra]) (2.5.2)
# Requirement already satisfied: tensorboard>=2.9.1 in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from stable-baselines3[extra]) (2.15.1)
# Requirement already satisfied: psutil in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from stable-baselines3[extra]) (5.9.7)
# Requirement already satisfied: tqdm in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from stable-baselines3[extra]) (4.66.1)
# Requirement already satisfied: rich in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from stable-baselines3[extra]) (13.7.0)
# Requirement already satisfied: shimmy~=1.3.0 in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from shimmy[atari]~=1.3.0; extra == "extra"->stable-baselines3[extra]) (1.3.0)
# Requirement already satisfied: pillow in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from stable-baselines3[extra]) (10.2.0)
# Requirement already satisfied: autorom~=0.6.1 in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (0.6.1)
# Requirement already satisfied: tensorflow-intel==2.15.0 in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (4.23.4)
# Requirement already satisfied: setuptools in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (4.9.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.60.0)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.15.0)
# Requirement already satisfied: click in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from autorom~=0.6.1->autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (8.1.7)
# Requirement already satisfied: AutoROM.accept-rom-license in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]) (0.6.1)
# Requirement already satisfied: soupsieve>1.2 in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: farama-notifications>=0.0.1 in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3[extra]) (0.0.4)
# Requirement already satisfied: webencodings in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from requests>=2.31->yfinance) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from requests>=2.31->yfinance) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from requests>=2.31->yfinance) (2023.11.17)
# Requirement already satisfied: ale-py~=0.8.1 in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from shimmy[atari]~=1.3.0; extra == "extra"->stable-baselines3[extra]) (0.8.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.26.1)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.5.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.0.1)
# Requirement already satisfied: filelock in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from torch>=1.13->stable-baselines3[extra]) (3.13.1)
# Requirement already satisfied: sympy in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from torch>=1.13->stable-baselines3[extra]) (1.12)
# Requirement already satisfied: networkx in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from torch>=1.13->stable-baselines3[extra]) (3.2.1)
# Requirement already satisfied: jinja2 in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from torch>=1.13->stable-baselines3[extra]) (3.1.2)
# Requirement already satisfied: fsspec in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from torch>=1.13->stable-baselines3[extra]) (2023.12.2)
# Requirement already satisfied: contourpy>=1.0.1 in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from matplotlib->stable-baselines3[extra]) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from matplotlib->stable-baselines3[extra]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from matplotlib->stable-baselines3[extra]) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from matplotlib->stable-baselines3[extra]) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from matplotlib->stable-baselines3[extra]) (3.1.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from rich->stable-baselines3[extra]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from rich->stable-baselines3[extra]) (2.17.2)
# Requirement already satisfied: colorama in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from tqdm->stable-baselines3[extra]) (0.4.6)
# Requirement already satisfied: importlib-resources in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from ale-py~=0.8.1->shimmy[atari]~=1.3.0; extra == "extra"->stable-baselines3[extra]) (6.1.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.15.0->tensorflow) (0.42.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]) (1.3.1)
# Requirement already satisfied: mdurl~=0.1 in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from sympy->torch>=1.13->stable-baselines3[extra]) (1.3.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in d:\python_scripts\bolsa_de_valores_aprendizado_reforco\venv\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]) (3.2.2)

# %% [markdown]
# ## Criação do ambiente

# %%
import gym
import numpy as np
import yfinance as yf
import time
import tensorflow as tf
from stable_baselines3 import ppo

# %%
class MercadoFinanceiro(gym.Env):
    
    def __init__(self, data):
        super(MercadoFinanceiro, self).__init__()
        # Inicializa o ambiente com a série temporal de preços, espaço de ação e espaço de observação.
        self.data = data
        self.action_space = gym.spaces.Discrete(2) # Comprar (0) ou Vender (1)
        self.observation_space = gym.spaces.Box(low=0, high=np.inf, shape=(2,), dtype=np.float32)
        
    def reset(self):
        # Reinicia o ambiente para o início de um episódio.
        self.current_step = 0
        self.profit = 0  # Lucro
        self.shares = 0  # Quantidade de ações da bolsa
        return self._get_observation()
    
    def step(self, action):
        # Executa uma etapa do ambiente com base na ação fornecida.
        assert self.action_space.contains(action), "Ação inválida!"
        done = False
        
        # Obtém os preços de compra e atual com base no histórico de preços.
        price_buy = self.data[self.current_step]
        price_current = self.data[self.current_step + 1]
        
        if action == 0:  # Comprar
            # Atualiza as ações e o lucro com base na ação de compra.
            self.shares += 1
            self.profit -= price_buy
            
        elif action == 1:  # Vender
            # Atualiza as ações e o lucro com base na ação de venda.
            if self.shares > 0:
                self.shares -= 1
                self.profit += price_current
                
        # Atualiza o passo atual.
        self.current_step += 1
        
        # Verifica se o episódio terminou.
        if self.current_step == len(self.data) - 1:
            done = True
            
        # Retorna a observação atualizada, o lucro, se o episódio terminou e informações adicionais.
        return self._get_observation(), self.profit, done, {}
    
    def _get_observation(self):
        # Retorna a observação atual, que consiste nos preços atual e próximo.
        if self.current_step == len(self.data) - 1:
            return np.zeros(2)
        
        return np.array([self.data[self.current_step], self.data[self.current_step + 1]])

# %% [markdown]
# ## criação do agente: modelo

# %%
def train_agent(env, num_steps):
    # Define a política do agente como uma rede neural com duas camadas ocultas de 64 unidades cada e uma camada de saída com o número de ações no espaço de ação do ambiente.
    policy = tf.keras.Sequential([
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Dense(env.action_space.n)
    ])

    # Define o otimizador Adam com uma taxa de aprendizado de 0.0001.
    optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)

    # Loop de treinamento principal.
    for iteration in range(num_steps):
        # Reseta o ambiente para o início de um episódio.
        obs = env.reset()

        # Variável para indicar se o episódio terminou.
        done = False

        # Inicia o tape para gravar operações para o cálculo do gradiente.
        with tf.GradientTape() as tape:
            # Loop para interagir com o ambiente até que o episódio termine.
            while not done:
                # Obtém as logits da política para a observação atual.
                logits = policy(tf.convert_to_tensor(obs[None, :], dtype=tf.float32))
                # Amostra uma ação estocasticamente a partir das logits.
                action = tf.random.categorical(logits, num_samples=1)[0, 0]
                action = int(action.numpy())  # Converte a ação para um inteiro.

                # Executa a ação no ambiente e obtém a próxima observação, recompensa, e se o episódio terminou.
                next_obs, reward, done, _ = env.step(action)

                # Atualiza a observação para a próxima iteração.
                obs = next_obs

                # Se o episódio terminou, sai do loop.
                if done:
                    break

            # Calcula a loss, penalizando ou recompensando com base na recompensa final do episódio.
            loss = -tf.reduce_mean(logits) if reward > 0 else tf.reduce_mean(logits)

        # Calcula os gradientes da loss em relação aos parâmetros da política.
        grads = tape.gradient(loss, policy.trainable_variables)
        # Aplica os gradientes usando o otimizador.
        optimizer.apply_gradients(zip(grads, policy.trainable_variables))

        # Calcula a recompensa total ao longo do episódio.
        total_reward = env.profit

        # Calcula o percentual de lucro em relação ao investimento inicial.
        percentual_lucro = ((total_reward / investimento_inicial) + 1) * 100

        # Imprime informações sobre a iteração atual.
        print(f"Iteração {iteration + 1}: | Lucro absoluto: R${total_reward:.2f} | Lucro percentual: {percentual_lucro:.2f}%")
        
    return policy

# %%
def test_agent(env, policy):
    # Reseta o ambiente para o início de um episódio.
    obs = env.reset()
    
    # Variável para indicar se o episódio terminou.
    done = False
    
    # Loop para interagir com o ambiente até que o episódio termine.
    while not done:
        # Obtém as logits da política para a observação atual.
        logits = policy(tf.convert_to_tensor(obs[None, :], dtype=tf.float32))
        
        # Escolhe a ação com a maior probabilidade (argmax das logits).
        action = tf.argmax(logits, axis=1)[0]
        action = int(action.numpy())  # Converte a ação para um inteiro.
        
        # Executa a ação no ambiente e obtém a próxima observação, recompensa, e se o episódio terminou.
        obs, reward, done, _ = env.step(action)
    
    # Retorna o lucro total obtido durante o episódio.
    return env.profit

# %% [markdown]
# ## Passando os dados: treinando e avaliando efetivamente o nosso projeto

# %%
#obtém a série histórica de ações do Banco do Brasil (BBAS3)
data = yf.download('BBAS3.SA', start='2021-12-25', end='2024-01-05')['Close'].values

# Normalizando os preços para o intervalo [0, 1]
normalized_data = (data - np.min(data)) / (np.max(data) - np.min(data))

# Criação do ambiente
env = MercadoFinanceiro(normalized_data)

# Definindo o valor do investimento inicial
investimento_inicial = 10000

# Treinamento do agente
policy = train_agent(env, num_steps=1000) # num_steps quantas repetições de teste

# Teste final do agente
final_profit = test_agent(env, policy)
percentual_lucro = (final_profit / investimento_inicial + 1) * 100

print(f"Lucro final em valor: R$ {final_profit:.2f}")
print(f"Lucro final em percentual: {percentual_lucro:.2f}%")
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Iteração 1: | Lucro absoluto: R$0.11 | Lucro percentual: 100.00%
# Iteração 2: | Lucro absoluto: R$7.99 | Lucro percentual: 100.08%
# Iteração 3: | Lucro absoluto: R$-3.23 | Lucro percentual: 99.97%
# Iteração 4: | Lucro absoluto: R$4.35 | Lucro percentual: 100.04%
# Iteração 5: | Lucro absoluto: R$-5.54 | Lucro percentual: 99.94%
# Iteração 6: | Lucro absoluto: R$5.01 | Lucro percentual: 100.05%
# Iteração 7: | Lucro absoluto: R$-1.63 | Lucro percentual: 99.98%
# Iteração 8: | Lucro absoluto: R$-7.28 | Lucro percentual: 99.93%
# Iteração 9: | Lucro absoluto: R$3.82 | Lucro percentual: 100.04%
# Iteração 10: | Lucro absoluto: R$4.69 | Lucro percentual: 100.05%
# Iteração 11: | Lucro absoluto: R$8.02 | Lucro percentual: 100.08%
# Iteração 12: | Lucro absoluto: R$4.89 | Lucro percentual: 100.05%
# Iteração 13: | Lucro absoluto: R$0.07 | Lucro percentual: 100.00%
# Iteração 14: | Lucro absoluto: R$-4.14 | Lucro percentual: 99.96%
# Iteração 15: | Lucro absoluto: R$4.92 | Lucro percentual: 100.05%
# Iteração 16: | Lucro absoluto: R$8.25 | Lucro percentual: 100.08%
# Iteração 17: | Lucro absoluto: R$3.96 | Lucro percentual: 100.04%
# Iteração 18: | Lucro absoluto: R$0.79 | Lucro percentual: 100.01%
# Iteração 19: | Lucro absoluto: R$0.45 | Lucro percentual: 100.00%
# Iteração 20: | Lucro absoluto: R$-26.73 | Lucro percentual: 99.73%
# Iteração 21: | Lucro absoluto: R$-8.56 | Lucro percentual: 99.91%
# Iteração 22: | Lucro absoluto: R$-5.06 | Lucro percentual: 99.95%
# Iteração 23: | Lucro absoluto: R$8.45 | Lucro percentual: 100.08%
# Iteração 24: | Lucro absoluto: R$5.62 | Lucro percentual: 100.06%
# Iteração 25: | Lucro absoluto: R$4.45 | Lucro percentual: 100.04%
# Iteração 26: | Lucro absoluto: R$0.81 | Lucro percentual: 100.01%
# Iteração 27: | Lucro absoluto: R$-4.38 | Lucro percentual: 99.96%
# Iteração 28: | Lucro absoluto: R$-6.59 | Lucro percentual: 99.93%
# Iteração 29: | Lucro absoluto: R$2.85 | Lucro percentual: 100.03%
# Iteração 30: | Lucro absoluto: R$-2.07 | Lucro percentual: 99.98%
# Iteração 31: | Lucro absoluto: R$-3.04 | Lucro percentual: 99.97%
# Iteração 32: | Lucro absoluto: R$3.56 | Lucro percentual: 100.04%
# Iteração 33: | Lucro absoluto: R$2.34 | Lucro percentual: 100.02%
# Iteração 34: | Lucro absoluto: R$8.95 | Lucro percentual: 100.09%
# Iteração 35: | Lucro absoluto: R$-3.27 | Lucro percentual: 99.97%
# Iteração 36: | Lucro absoluto: R$4.72 | Lucro percentual: 100.05%
# Iteração 37: | Lucro absoluto: R$5.89 | Lucro percentual: 100.06%
# Iteração 38: | Lucro absoluto: R$0.95 | Lucro percentual: 100.01%
# Iteração 39: | Lucro absoluto: R$-11.33 | Lucro percentual: 99.89%
# Iteração 40: | Lucro absoluto: R$-12.57 | Lucro percentual: 99.87%
# Iteração 41: | Lucro absoluto: R$8.18 | Lucro percentual: 100.08%
# Iteração 42: | Lucro absoluto: R$6.18 | Lucro percentual: 100.06%
# Iteração 43: | Lucro absoluto: R$-16.16 | Lucro percentual: 99.84%
# Iteração 44: | Lucro absoluto: R$5.45 | Lucro percentual: 100.05%
# Iteração 45: | Lucro absoluto: R$3.79 | Lucro percentual: 100.04%
# Iteração 46: | Lucro absoluto: R$0.01 | Lucro percentual: 100.00%
# Iteração 47: | Lucro absoluto: R$3.26 | Lucro percentual: 100.03%
# Iteração 48: | Lucro absoluto: R$0.52 | Lucro percentual: 100.01%
# Iteração 49: | Lucro absoluto: R$-0.83 | Lucro percentual: 99.99%
# Iteração 50: | Lucro absoluto: R$-21.54 | Lucro percentual: 99.78%
# Iteração 51: | Lucro absoluto: R$11.15 | Lucro percentual: 100.11%
# Iteração 52: | Lucro absoluto: R$4.04 | Lucro percentual: 100.04%
# Iteração 53: | Lucro absoluto: R$5.95 | Lucro percentual: 100.06%
# Iteração 54: | Lucro absoluto: R$-7.31 | Lucro percentual: 99.93%
# Iteração 55: | Lucro absoluto: R$-0.96 | Lucro percentual: 99.99%
# Iteração 56: | Lucro absoluto: R$-2.17 | Lucro percentual: 99.98%
# Iteração 57: | Lucro absoluto: R$3.48 | Lucro percentual: 100.03%
# Iteração 58: | Lucro absoluto: R$4.59 | Lucro percentual: 100.05%
# Iteração 59: | Lucro absoluto: R$-2.27 | Lucro percentual: 99.98%
# Iteração 60: | Lucro absoluto: R$-21.65 | Lucro percentual: 99.78%
# Iteração 61: | Lucro absoluto: R$1.47 | Lucro percentual: 100.01%
# Iteração 62: | Lucro absoluto: R$4.58 | Lucro percentual: 100.05%
# Iteração 63: | Lucro absoluto: R$-2.50 | Lucro percentual: 99.98%
# Iteração 64: | Lucro absoluto: R$-13.52 | Lucro percentual: 99.86%
# Iteração 65: | Lucro absoluto: R$-1.39 | Lucro percentual: 99.99%
# Iteração 66: | Lucro absoluto: R$-23.98 | Lucro percentual: 99.76%
# Iteração 67: | Lucro absoluto: R$-13.11 | Lucro percentual: 99.87%
# Iteração 68: | Lucro absoluto: R$4.60 | Lucro percentual: 100.05%
# Iteração 69: | Lucro absoluto: R$6.43 | Lucro percentual: 100.06%
# Iteração 70: | Lucro absoluto: R$4.93 | Lucro percentual: 100.05%
# Iteração 71: | Lucro absoluto: R$-14.19 | Lucro percentual: 99.86%
# Iteração 72: | Lucro absoluto: R$-5.06 | Lucro percentual: 99.95%
# Iteração 73: | Lucro absoluto: R$-6.67 | Lucro percentual: 99.93%
# Iteração 74: | Lucro absoluto: R$-2.90 | Lucro percentual: 99.97%
# Iteração 75: | Lucro absoluto: R$-9.72 | Lucro percentual: 99.90%
# Iteração 76: | Lucro absoluto: R$-4.18 | Lucro percentual: 99.96%
# Iteração 77: | Lucro absoluto: R$3.87 | Lucro percentual: 100.04%
# Iteração 78: | Lucro absoluto: R$-9.24 | Lucro percentual: 99.91%
# Iteração 79: | Lucro absoluto: R$-4.68 | Lucro percentual: 99.95%
# Iteração 80: | Lucro absoluto: R$1.50 | Lucro percentual: 100.01%
# Iteração 81: | Lucro absoluto: R$-6.70 | Lucro percentual: 99.93%
# Iteração 82: | Lucro absoluto: R$-3.56 | Lucro percentual: 99.96%
# Iteração 83: | Lucro absoluto: R$2.64 | Lucro percentual: 100.03%
# Iteração 84: | Lucro absoluto: R$4.28 | Lucro percentual: 100.04%
# Iteração 85: | Lucro absoluto: R$4.45 | Lucro percentual: 100.04%
# Iteração 86: | Lucro absoluto: R$7.52 | Lucro percentual: 100.08%
# Iteração 87: | Lucro absoluto: R$-30.42 | Lucro percentual: 99.70%
# Iteração 88: | Lucro absoluto: R$1.37 | Lucro percentual: 100.01%
# Iteração 89: | Lucro absoluto: R$2.68 | Lucro percentual: 100.03%
# Iteração 90: | Lucro absoluto: R$-4.06 | Lucro percentual: 99.96%
# Iteração 91: | Lucro absoluto: R$-4.36 | Lucro percentual: 99.96%
# Iteração 92: | Lucro absoluto: R$2.06 | Lucro percentual: 100.02%
# Iteração 93: | Lucro absoluto: R$8.59 | Lucro percentual: 100.09%
# Iteração 94: | Lucro absoluto: R$1.92 | Lucro percentual: 100.02%
# Iteração 95: | Lucro absoluto: R$-5.30 | Lucro percentual: 99.95%
# Iteração 96: | Lucro absoluto: R$-0.99 | Lucro percentual: 99.99%
# Iteração 97: | Lucro absoluto: R$0.19 | Lucro percentual: 100.00%
# Iteração 98: | Lucro absoluto: R$7.23 | Lucro percentual: 100.07%
# Iteração 99: | Lucro absoluto: R$9.11 | Lucro percentual: 100.09%
# Iteração 100: | Lucro absoluto: R$-2.09 | Lucro percentual: 99.98%
# Iteração 101: | Lucro absoluto: R$4.26 | Lucro percentual: 100.04%
# Iteração 102: | Lucro absoluto: R$-7.23 | Lucro percentual: 99.93%
# Iteração 103: | Lucro absoluto: R$-4.42 | Lucro percentual: 99.96%
# Iteração 104: | Lucro absoluto: R$6.60 | Lucro percentual: 100.07%
# Iteração 105: | Lucro absoluto: R$-11.98 | Lucro percentual: 99.88%
# Iteração 106: | Lucro absoluto: R$-1.13 | Lucro percentual: 99.99%
# Iteração 107: | Lucro absoluto: R$0.88 | Lucro percentual: 100.01%
# Iteração 108: | Lucro absoluto: R$3.85 | Lucro percentual: 100.04%
# Iteração 109: | Lucro absoluto: R$1.80 | Lucro percentual: 100.02%
# Iteração 110: | Lucro absoluto: R$2.40 | Lucro percentual: 100.02%
# Iteração 111: | Lucro absoluto: R$-0.58 | Lucro percentual: 99.99%
# Iteração 112: | Lucro absoluto: R$5.62 | Lucro percentual: 100.06%
# Iteração 113: | Lucro absoluto: R$1.29 | Lucro percentual: 100.01%
# Iteração 114: | Lucro absoluto: R$-6.60 | Lucro percentual: 99.93%
# Iteração 115: | Lucro absoluto: R$3.81 | Lucro percentual: 100.04%
# Iteração 116: | Lucro absoluto: R$-7.21 | Lucro percentual: 99.93%
# Iteração 117: | Lucro absoluto: R$-13.42 | Lucro percentual: 99.87%
# Iteração 118: | Lucro absoluto: R$-18.63 | Lucro percentual: 99.81%
# Iteração 119: | Lucro absoluto: R$-4.46 | Lucro percentual: 99.96%
# Iteração 120: | Lucro absoluto: R$-3.87 | Lucro percentual: 99.96%
# Iteração 121: | Lucro absoluto: R$-3.10 | Lucro percentual: 99.97%
# Iteração 122: | Lucro absoluto: R$3.98 | Lucro percentual: 100.04%
# Iteração 123: | Lucro absoluto: R$-10.20 | Lucro percentual: 99.90%
# Iteração 124: | Lucro absoluto: R$4.03 | Lucro percentual: 100.04%
# Iteração 125: | Lucro absoluto: R$1.51 | Lucro percentual: 100.02%
# Iteração 126: | Lucro absoluto: R$5.81 | Lucro percentual: 100.06%
# Iteração 127: | Lucro absoluto: R$-2.20 | Lucro percentual: 99.98%
# Iteração 128: | Lucro absoluto: R$-6.97 | Lucro percentual: 99.93%
# Iteração 129: | Lucro absoluto: R$-11.80 | Lucro percentual: 99.88%
# Iteração 130: | Lucro absoluto: R$-2.90 | Lucro percentual: 99.97%
# Iteração 131: | Lucro absoluto: R$-9.19 | Lucro percentual: 99.91%
# Iteração 132: | Lucro absoluto: R$-0.21 | Lucro percentual: 100.00%
# Iteração 133: | Lucro absoluto: R$-14.98 | Lucro percentual: 99.85%
# Iteração 134: | Lucro absoluto: R$-1.90 | Lucro percentual: 99.98%
# Iteração 135: | Lucro absoluto: R$-9.32 | Lucro percentual: 99.91%
# Iteração 136: | Lucro absoluto: R$1.15 | Lucro percentual: 100.01%
# Iteração 137: | Lucro absoluto: R$-4.11 | Lucro percentual: 99.96%
# Iteração 138: | Lucro absoluto: R$5.31 | Lucro percentual: 100.05%
# Iteração 139: | Lucro absoluto: R$1.23 | Lucro percentual: 100.01%
# Iteração 140: | Lucro absoluto: R$-9.17 | Lucro percentual: 99.91%
# Iteração 141: | Lucro absoluto: R$-21.81 | Lucro percentual: 99.78%
# Iteração 142: | Lucro absoluto: R$11.19 | Lucro percentual: 100.11%
# Iteração 143: | Lucro absoluto: R$-2.39 | Lucro percentual: 99.98%
# Iteração 144: | Lucro absoluto: R$-0.46 | Lucro percentual: 100.00%
# Iteração 145: | Lucro absoluto: R$-9.90 | Lucro percentual: 99.90%
# Iteração 146: | Lucro absoluto: R$3.56 | Lucro percentual: 100.04%
# Iteração 147: | Lucro absoluto: R$-0.03 | Lucro percentual: 100.00%
# Iteração 148: | Lucro absoluto: R$4.07 | Lucro percentual: 100.04%
# Iteração 149: | Lucro absoluto: R$-0.27 | Lucro percentual: 100.00%
# Iteração 150: | Lucro absoluto: R$-11.22 | Lucro percentual: 99.89%
# Iteração 151: | Lucro absoluto: R$6.67 | Lucro percentual: 100.07%
# Iteração 152: | Lucro absoluto: R$-10.41 | Lucro percentual: 99.90%
# Iteração 153: | Lucro absoluto: R$4.79 | Lucro percentual: 100.05%
# Iteração 154: | Lucro absoluto: R$1.82 | Lucro percentual: 100.02%
# Iteração 155: | Lucro absoluto: R$-2.56 | Lucro percentual: 99.97%
# Iteração 156: | Lucro absoluto: R$-5.14 | Lucro percentual: 99.95%
# Iteração 157: | Lucro absoluto: R$0.67 | Lucro percentual: 100.01%
# Iteração 158: | Lucro absoluto: R$-10.83 | Lucro percentual: 99.89%
# Iteração 159: | Lucro absoluto: R$11.75 | Lucro percentual: 100.12%
# Iteração 160: | Lucro absoluto: R$-15.60 | Lucro percentual: 99.84%
# Iteração 161: | Lucro absoluto: R$-8.68 | Lucro percentual: 99.91%
# Iteração 162: | Lucro absoluto: R$-0.14 | Lucro percentual: 100.00%
# Iteração 163: | Lucro absoluto: R$-13.84 | Lucro percentual: 99.86%
# Iteração 164: | Lucro absoluto: R$3.26 | Lucro percentual: 100.03%
# Iteração 165: | Lucro absoluto: R$6.94 | Lucro percentual: 100.07%
# Iteração 166: | Lucro absoluto: R$2.30 | Lucro percentual: 100.02%
# Iteração 167: | Lucro absoluto: R$5.44 | Lucro percentual: 100.05%
# Iteração 168: | Lucro absoluto: R$-0.51 | Lucro percentual: 99.99%
# Iteração 169: | Lucro absoluto: R$-0.93 | Lucro percentual: 99.99%
# Iteração 170: | Lucro absoluto: R$2.88 | Lucro percentual: 100.03%
# Iteração 171: | Lucro absoluto: R$4.07 | Lucro percentual: 100.04%
# Iteração 172: | Lucro absoluto: R$-0.34 | Lucro percentual: 100.00%
# Iteração 173: | Lucro absoluto: R$2.84 | Lucro percentual: 100.03%
# Iteração 174: | Lucro absoluto: R$-2.51 | Lucro percentual: 99.97%
# Iteração 175: | Lucro absoluto: R$-11.70 | Lucro percentual: 99.88%
# Iteração 176: | Lucro absoluto: R$-0.43 | Lucro percentual: 100.00%
# Iteração 177: | Lucro absoluto: R$1.16 | Lucro percentual: 100.01%
# Iteração 178: | Lucro absoluto: R$-7.52 | Lucro percentual: 99.92%
# Iteração 179: | Lucro absoluto: R$-15.12 | Lucro percentual: 99.85%
# Iteração 180: | Lucro absoluto: R$-0.19 | Lucro percentual: 100.00%
# Iteração 181: | Lucro absoluto: R$2.91 | Lucro percentual: 100.03%
# Iteração 182: | Lucro absoluto: R$-12.82 | Lucro percentual: 99.87%
# Iteração 183: | Lucro absoluto: R$1.37 | Lucro percentual: 100.01%
# Iteração 184: | Lucro absoluto: R$-1.90 | Lucro percentual: 99.98%
# Iteração 185: | Lucro absoluto: R$12.34 | Lucro percentual: 100.12%
# Iteração 186: | Lucro absoluto: R$3.41 | Lucro percentual: 100.03%
# Iteração 187: | Lucro absoluto: R$4.24 | Lucro percentual: 100.04%
# Iteração 188: | Lucro absoluto: R$-3.48 | Lucro percentual: 99.97%
# Iteração 189: | Lucro absoluto: R$3.63 | Lucro percentual: 100.04%
# Iteração 190: | Lucro absoluto: R$2.05 | Lucro percentual: 100.02%
# Iteração 191: | Lucro absoluto: R$-5.02 | Lucro percentual: 99.95%
# Iteração 192: | Lucro absoluto: R$2.17 | Lucro percentual: 100.02%
# Iteração 193: | Lucro absoluto: R$7.99 | Lucro percentual: 100.08%
# Iteração 194: | Lucro absoluto: R$-11.66 | Lucro percentual: 99.88%
# Iteração 195: | Lucro absoluto: R$4.25 | Lucro percentual: 100.04%
# Iteração 196: | Lucro absoluto: R$-1.14 | Lucro percentual: 99.99%
# Iteração 197: | Lucro absoluto: R$3.13 | Lucro percentual: 100.03%
# Iteração 198: | Lucro absoluto: R$11.70 | Lucro percentual: 100.12%
# Iteração 199: | Lucro absoluto: R$6.40 | Lucro percentual: 100.06%
# Iteração 200: | Lucro absoluto: R$-9.88 | Lucro percentual: 99.90%
# Iteração 201: | Lucro absoluto: R$-6.97 | Lucro percentual: 99.93%
# Iteração 202: | Lucro absoluto: R$5.38 | Lucro percentual: 100.05%
# Iteração 203: | Lucro absoluto: R$2.93 | Lucro percentual: 100.03%
# Iteração 204: | Lucro absoluto: R$1.88 | Lucro percentual: 100.02%
# Iteração 205: | Lucro absoluto: R$6.83 | Lucro percentual: 100.07%
# Iteração 206: | Lucro absoluto: R$0.29 | Lucro percentual: 100.00%
# Iteração 207: | Lucro absoluto: R$7.77 | Lucro percentual: 100.08%
# Iteração 208: | Lucro absoluto: R$-1.89 | Lucro percentual: 99.98%
# Iteração 209: | Lucro absoluto: R$-0.47 | Lucro percentual: 100.00%
# Iteração 210: | Lucro absoluto: R$-0.34 | Lucro percentual: 100.00%
# Iteração 211: | Lucro absoluto: R$-1.45 | Lucro percentual: 99.99%
# Iteração 212: | Lucro absoluto: R$-5.59 | Lucro percentual: 99.94%
# Iteração 213: | Lucro absoluto: R$-1.06 | Lucro percentual: 99.99%
# Iteração 214: | Lucro absoluto: R$-1.15 | Lucro percentual: 99.99%
# Iteração 215: | Lucro absoluto: R$0.23 | Lucro percentual: 100.00%
# Iteração 216: | Lucro absoluto: R$11.71 | Lucro percentual: 100.12%
# Iteração 217: | Lucro absoluto: R$4.33 | Lucro percentual: 100.04%
# Iteração 218: | Lucro absoluto: R$-1.09 | Lucro percentual: 99.99%
# Iteração 219: | Lucro absoluto: R$2.62 | Lucro percentual: 100.03%
# Iteração 220: | Lucro absoluto: R$1.19 | Lucro percentual: 100.01%
# Iteração 221: | Lucro absoluto: R$4.80 | Lucro percentual: 100.05%
# Iteração 222: | Lucro absoluto: R$2.89 | Lucro percentual: 100.03%
# Iteração 223: | Lucro absoluto: R$0.52 | Lucro percentual: 100.01%
# Iteração 224: | Lucro absoluto: R$-4.70 | Lucro percentual: 99.95%
# Iteração 225: | Lucro absoluto: R$-6.74 | Lucro percentual: 99.93%
# Iteração 226: | Lucro absoluto: R$-8.10 | Lucro percentual: 99.92%
# Iteração 227: | Lucro absoluto: R$-0.29 | Lucro percentual: 100.00%
# Iteração 228: | Lucro absoluto: R$2.61 | Lucro percentual: 100.03%
# Iteração 229: | Lucro absoluto: R$0.38 | Lucro percentual: 100.00%
# Iteração 230: | Lucro absoluto: R$4.23 | Lucro percentual: 100.04%
# Iteração 231: | Lucro absoluto: R$-0.27 | Lucro percentual: 100.00%
# Iteração 232: | Lucro absoluto: R$-2.42 | Lucro percentual: 99.98%
# Iteração 233: | Lucro absoluto: R$-0.63 | Lucro percentual: 99.99%
# Iteração 234: | Lucro absoluto: R$0.29 | Lucro percentual: 100.00%
# Iteração 235: | Lucro absoluto: R$4.99 | Lucro percentual: 100.05%
# Iteração 236: | Lucro absoluto: R$-13.35 | Lucro percentual: 99.87%
# Iteração 237: | Lucro absoluto: R$4.92 | Lucro percentual: 100.05%
# Iteração 238: | Lucro absoluto: R$1.54 | Lucro percentual: 100.02%
# Iteração 239: | Lucro absoluto: R$3.49 | Lucro percentual: 100.03%
# Iteração 240: | Lucro absoluto: R$-8.62 | Lucro percentual: 99.91%
# Iteração 241: | Lucro absoluto: R$-1.74 | Lucro percentual: 99.98%
# Iteração 242: | Lucro absoluto: R$-2.69 | Lucro percentual: 99.97%
# Iteração 243: | Lucro absoluto: R$10.95 | Lucro percentual: 100.11%
# Iteração 244: | Lucro absoluto: R$-3.87 | Lucro percentual: 99.96%
# Iteração 245: | Lucro absoluto: R$-3.74 | Lucro percentual: 99.96%
# Iteração 246: | Lucro absoluto: R$0.97 | Lucro percentual: 100.01%
# Iteração 247: | Lucro absoluto: R$0.19 | Lucro percentual: 100.00%
# Iteração 248: | Lucro absoluto: R$3.91 | Lucro percentual: 100.04%
# Iteração 249: | Lucro absoluto: R$-1.48 | Lucro percentual: 99.99%
# Iteração 250: | Lucro absoluto: R$-0.52 | Lucro percentual: 99.99%
# Iteração 251: | Lucro absoluto: R$4.33 | Lucro percentual: 100.04%
# Iteração 252: | Lucro absoluto: R$-8.79 | Lucro percentual: 99.91%
# Iteração 253: | Lucro absoluto: R$12.33 | Lucro percentual: 100.12%
# Iteração 254: | Lucro absoluto: R$5.20 | Lucro percentual: 100.05%
# Iteração 255: | Lucro absoluto: R$-9.16 | Lucro percentual: 99.91%
# Iteração 256: | Lucro absoluto: R$-0.70 | Lucro percentual: 99.99%
# Iteração 257: | Lucro absoluto: R$-5.01 | Lucro percentual: 99.95%
# Iteração 258: | Lucro absoluto: R$-16.53 | Lucro percentual: 99.83%
# Iteração 259: | Lucro absoluto: R$-3.45 | Lucro percentual: 99.97%
# Iteração 260: | Lucro absoluto: R$-3.92 | Lucro percentual: 99.96%
# Iteração 261: | Lucro absoluto: R$-12.82 | Lucro percentual: 99.87%
# Iteração 262: | Lucro absoluto: R$0.19 | Lucro percentual: 100.00%
# Iteração 263: | Lucro absoluto: R$8.73 | Lucro percentual: 100.09%
# Iteração 264: | Lucro absoluto: R$-6.20 | Lucro percentual: 99.94%
# Iteração 265: | Lucro absoluto: R$-3.51 | Lucro percentual: 99.96%
# Iteração 266: | Lucro absoluto: R$-15.98 | Lucro percentual: 99.84%
# Iteração 267: | Lucro absoluto: R$1.84 | Lucro percentual: 100.02%
# Iteração 268: | Lucro absoluto: R$4.00 | Lucro percentual: 100.04%
# Iteração 269: | Lucro absoluto: R$5.25 | Lucro percentual: 100.05%
# Iteração 270: | Lucro absoluto: R$2.98 | Lucro percentual: 100.03%
# Iteração 271: | Lucro absoluto: R$-14.41 | Lucro percentual: 99.86%
# Iteração 272: | Lucro absoluto: R$-8.50 | Lucro percentual: 99.92%
# Iteração 273: | Lucro absoluto: R$9.08 | Lucro percentual: 100.09%
# Iteração 274: | Lucro absoluto: R$-3.30 | Lucro percentual: 99.97%
# Iteração 275: | Lucro absoluto: R$-8.76 | Lucro percentual: 99.91%
# Iteração 276: | Lucro absoluto: R$2.19 | Lucro percentual: 100.02%
# Iteração 277: | Lucro absoluto: R$-0.50 | Lucro percentual: 99.99%
# Iteração 278: | Lucro absoluto: R$-1.48 | Lucro percentual: 99.99%
# Iteração 279: | Lucro absoluto: R$-7.97 | Lucro percentual: 99.92%
# Iteração 280: | Lucro absoluto: R$5.01 | Lucro percentual: 100.05%
# Iteração 281: | Lucro absoluto: R$5.13 | Lucro percentual: 100.05%
# Iteração 282: | Lucro absoluto: R$-8.32 | Lucro percentual: 99.92%
# Iteração 283: | Lucro absoluto: R$-6.99 | Lucro percentual: 99.93%
# Iteração 284: | Lucro absoluto: R$0.66 | Lucro percentual: 100.01%
# Iteração 285: | Lucro absoluto: R$3.45 | Lucro percentual: 100.03%
# Iteração 286: | Lucro absoluto: R$-8.29 | Lucro percentual: 99.92%
# Iteração 287: | Lucro absoluto: R$5.19 | Lucro percentual: 100.05%
# Iteração 288: | Lucro absoluto: R$-3.26 | Lucro percentual: 99.97%
# Iteração 289: | Lucro absoluto: R$1.36 | Lucro percentual: 100.01%
# Iteração 290: | Lucro absoluto: R$-12.76 | Lucro percentual: 99.87%
# Iteração 291: | Lucro absoluto: R$-1.69 | Lucro percentual: 99.98%
# Iteração 292: | Lucro absoluto: R$-0.57 | Lucro percentual: 99.99%
# Iteração 293: | Lucro absoluto: R$-13.92 | Lucro percentual: 99.86%
# Iteração 294: | Lucro absoluto: R$1.87 | Lucro percentual: 100.02%
# Iteração 295: | Lucro absoluto: R$-2.13 | Lucro percentual: 99.98%
# Iteração 296: | Lucro absoluto: R$10.71 | Lucro percentual: 100.11%
# Iteração 297: | Lucro absoluto: R$-8.07 | Lucro percentual: 99.92%
# Iteração 298: | Lucro absoluto: R$1.72 | Lucro percentual: 100.02%
# Iteração 299: | Lucro absoluto: R$2.73 | Lucro percentual: 100.03%
# Iteração 300: | Lucro absoluto: R$6.17 | Lucro percentual: 100.06%
# Iteração 301: | Lucro absoluto: R$-12.04 | Lucro percentual: 99.88%
# Iteração 302: | Lucro absoluto: R$2.70 | Lucro percentual: 100.03%
# Iteração 303: | Lucro absoluto: R$9.82 | Lucro percentual: 100.10%
# Iteração 304: | Lucro absoluto: R$3.36 | Lucro percentual: 100.03%
# Iteração 305: | Lucro absoluto: R$-5.90 | Lucro percentual: 99.94%
# Iteração 306: | Lucro absoluto: R$-3.17 | Lucro percentual: 99.97%
# Iteração 307: | Lucro absoluto: R$-0.66 | Lucro percentual: 99.99%
# Iteração 308: | Lucro absoluto: R$5.10 | Lucro percentual: 100.05%
# Iteração 309: | Lucro absoluto: R$5.36 | Lucro percentual: 100.05%
# Iteração 310: | Lucro absoluto: R$1.58 | Lucro percentual: 100.02%
# Iteração 311: | Lucro absoluto: R$-2.50 | Lucro percentual: 99.97%
# Iteração 312: | Lucro absoluto: R$6.65 | Lucro percentual: 100.07%
# Iteração 313: | Lucro absoluto: R$-8.04 | Lucro percentual: 99.92%
# Iteração 314: | Lucro absoluto: R$0.60 | Lucro percentual: 100.01%
# Iteração 315: | Lucro absoluto: R$0.80 | Lucro percentual: 100.01%
# Iteração 316: | Lucro absoluto: R$-1.69 | Lucro percentual: 99.98%
# Iteração 317: | Lucro absoluto: R$-6.14 | Lucro percentual: 99.94%
# Iteração 318: | Lucro absoluto: R$0.65 | Lucro percentual: 100.01%
# Iteração 319: | Lucro absoluto: R$9.10 | Lucro percentual: 100.09%
# Iteração 320: | Lucro absoluto: R$0.80 | Lucro percentual: 100.01%
# Iteração 321: | Lucro absoluto: R$4.72 | Lucro percentual: 100.05%
# Iteração 322: | Lucro absoluto: R$0.58 | Lucro percentual: 100.01%
# Iteração 323: | Lucro absoluto: R$5.78 | Lucro percentual: 100.06%
# Iteração 324: | Lucro absoluto: R$-4.65 | Lucro percentual: 99.95%
# Iteração 325: | Lucro absoluto: R$3.97 | Lucro percentual: 100.04%
# Iteração 326: | Lucro absoluto: R$4.67 | Lucro percentual: 100.05%
# Iteração 327: | Lucro absoluto: R$-8.14 | Lucro percentual: 99.92%
# Iteração 328: | Lucro absoluto: R$10.15 | Lucro percentual: 100.10%
# Iteração 329: | Lucro absoluto: R$3.61 | Lucro percentual: 100.04%
# Iteração 330: | Lucro absoluto: R$-11.74 | Lucro percentual: 99.88%
# Iteração 331: | Lucro absoluto: R$-2.29 | Lucro percentual: 99.98%
# Iteração 332: | Lucro absoluto: R$-5.69 | Lucro percentual: 99.94%
# Iteração 333: | Lucro absoluto: R$-1.73 | Lucro percentual: 99.98%
# Iteração 334: | Lucro absoluto: R$4.95 | Lucro percentual: 100.05%
# Iteração 335: | Lucro absoluto: R$2.47 | Lucro percentual: 100.02%
# Iteração 336: | Lucro absoluto: R$-6.50 | Lucro percentual: 99.93%
# Iteração 337: | Lucro absoluto: R$5.04 | Lucro percentual: 100.05%
# Iteração 338: | Lucro absoluto: R$2.88 | Lucro percentual: 100.03%
# Iteração 339: | Lucro absoluto: R$-11.46 | Lucro percentual: 99.89%
# Iteração 340: | Lucro absoluto: R$6.18 | Lucro percentual: 100.06%
# Iteração 341: | Lucro absoluto: R$-8.19 | Lucro percentual: 99.92%
# Iteração 342: | Lucro absoluto: R$-0.84 | Lucro percentual: 99.99%
# Iteração 343: | Lucro absoluto: R$-1.51 | Lucro percentual: 99.98%
# Iteração 344: | Lucro absoluto: R$3.20 | Lucro percentual: 100.03%
# Iteração 345: | Lucro absoluto: R$-7.95 | Lucro percentual: 99.92%
# Iteração 346: | Lucro absoluto: R$1.69 | Lucro percentual: 100.02%
# Iteração 347: | Lucro absoluto: R$0.16 | Lucro percentual: 100.00%
# Iteração 348: | Lucro absoluto: R$6.55 | Lucro percentual: 100.07%
# Iteração 349: | Lucro absoluto: R$-1.99 | Lucro percentual: 99.98%
# Iteração 350: | Lucro absoluto: R$0.80 | Lucro percentual: 100.01%
# Iteração 351: | Lucro absoluto: R$17.61 | Lucro percentual: 100.18%
# Iteração 352: | Lucro absoluto: R$-18.04 | Lucro percentual: 99.82%
# Iteração 353: | Lucro absoluto: R$1.50 | Lucro percentual: 100.01%
# Iteração 354: | Lucro absoluto: R$-1.10 | Lucro percentual: 99.99%
# Iteração 355: | Lucro absoluto: R$5.38 | Lucro percentual: 100.05%
# Iteração 356: | Lucro absoluto: R$-4.35 | Lucro percentual: 99.96%
# Iteração 357: | Lucro absoluto: R$-0.07 | Lucro percentual: 100.00%
# Iteração 358: | Lucro absoluto: R$6.06 | Lucro percentual: 100.06%
# Iteração 359: | Lucro absoluto: R$-5.45 | Lucro percentual: 99.95%
# Iteração 360: | Lucro absoluto: R$-18.74 | Lucro percentual: 99.81%
# Iteração 361: | Lucro absoluto: R$0.05 | Lucro percentual: 100.00%
# Iteração 362: | Lucro absoluto: R$-9.06 | Lucro percentual: 99.91%
# Iteração 363: | Lucro absoluto: R$-2.46 | Lucro percentual: 99.98%
# Iteração 364: | Lucro absoluto: R$3.62 | Lucro percentual: 100.04%
# Iteração 365: | Lucro absoluto: R$15.26 | Lucro percentual: 100.15%
# Iteração 366: | Lucro absoluto: R$0.21 | Lucro percentual: 100.00%
# Iteração 367: | Lucro absoluto: R$5.17 | Lucro percentual: 100.05%
# Iteração 368: | Lucro absoluto: R$0.91 | Lucro percentual: 100.01%
# Iteração 369: | Lucro absoluto: R$5.51 | Lucro percentual: 100.06%
# Iteração 370: | Lucro absoluto: R$-2.17 | Lucro percentual: 99.98%
# Iteração 371: | Lucro absoluto: R$5.31 | Lucro percentual: 100.05%
# Iteração 372: | Lucro absoluto: R$3.33 | Lucro percentual: 100.03%
# Iteração 373: | Lucro absoluto: R$4.28 | Lucro percentual: 100.04%
# Iteração 374: | Lucro absoluto: R$-5.76 | Lucro percentual: 99.94%
# Iteração 375: | Lucro absoluto: R$15.97 | Lucro percentual: 100.16%
# Iteração 376: | Lucro absoluto: R$-2.14 | Lucro percentual: 99.98%
# Iteração 377: | Lucro absoluto: R$-11.43 | Lucro percentual: 99.89%
# Iteração 378: | Lucro absoluto: R$-0.94 | Lucro percentual: 99.99%
# Iteração 379: | Lucro absoluto: R$3.60 | Lucro percentual: 100.04%
# Iteração 380: | Lucro absoluto: R$7.36 | Lucro percentual: 100.07%
# Iteração 381: | Lucro absoluto: R$0.30 | Lucro percentual: 100.00%
# Iteração 382: | Lucro absoluto: R$-0.29 | Lucro percentual: 100.00%
# Iteração 383: | Lucro absoluto: R$-5.20 | Lucro percentual: 99.95%
# Iteração 384: | Lucro absoluto: R$-11.88 | Lucro percentual: 99.88%
# Iteração 385: | Lucro absoluto: R$3.56 | Lucro percentual: 100.04%
# Iteração 386: | Lucro absoluto: R$0.07 | Lucro percentual: 100.00%
# Iteração 387: | Lucro absoluto: R$1.60 | Lucro percentual: 100.02%
# Iteração 388: | Lucro absoluto: R$4.63 | Lucro percentual: 100.05%
# Iteração 389: | Lucro absoluto: R$2.90 | Lucro percentual: 100.03%
# Iteração 390: | Lucro absoluto: R$3.48 | Lucro percentual: 100.03%
# Iteração 391: | Lucro absoluto: R$8.27 | Lucro percentual: 100.08%
# Iteração 392: | Lucro absoluto: R$-4.79 | Lucro percentual: 99.95%
# Iteração 393: | Lucro absoluto: R$3.76 | Lucro percentual: 100.04%
# Iteração 394: | Lucro absoluto: R$-15.83 | Lucro percentual: 99.84%
# Iteração 395: | Lucro absoluto: R$0.08 | Lucro percentual: 100.00%
# Iteração 396: | Lucro absoluto: R$-5.41 | Lucro percentual: 99.95%
# Iteração 397: | Lucro absoluto: R$3.17 | Lucro percentual: 100.03%
# Iteração 398: | Lucro absoluto: R$-5.24 | Lucro percentual: 99.95%
# Iteração 399: | Lucro absoluto: R$4.91 | Lucro percentual: 100.05%
# Iteração 400: | Lucro absoluto: R$-6.63 | Lucro percentual: 99.93%
# Iteração 401: | Lucro absoluto: R$0.68 | Lucro percentual: 100.01%
# Iteração 402: | Lucro absoluto: R$-3.04 | Lucro percentual: 99.97%
# Iteração 403: | Lucro absoluto: R$2.13 | Lucro percentual: 100.02%
# Iteração 404: | Lucro absoluto: R$5.18 | Lucro percentual: 100.05%
# Iteração 405: | Lucro absoluto: R$-8.22 | Lucro percentual: 99.92%
# Iteração 406: | Lucro absoluto: R$7.71 | Lucro percentual: 100.08%
# Iteração 407: | Lucro absoluto: R$2.26 | Lucro percentual: 100.02%
# Iteração 408: | Lucro absoluto: R$4.34 | Lucro percentual: 100.04%
# Iteração 409: | Lucro absoluto: R$0.36 | Lucro percentual: 100.00%
# Iteração 410: | Lucro absoluto: R$4.24 | Lucro percentual: 100.04%
# Iteração 411: | Lucro absoluto: R$-17.97 | Lucro percentual: 99.82%
# Iteração 412: | Lucro absoluto: R$-5.00 | Lucro percentual: 99.95%
# Iteração 413: | Lucro absoluto: R$2.03 | Lucro percentual: 100.02%
# Iteração 414: | Lucro absoluto: R$0.18 | Lucro percentual: 100.00%
# Iteração 415: | Lucro absoluto: R$4.62 | Lucro percentual: 100.05%
# Iteração 416: | Lucro absoluto: R$0.39 | Lucro percentual: 100.00%
# Iteração 417: | Lucro absoluto: R$-2.43 | Lucro percentual: 99.98%
# Iteração 418: | Lucro absoluto: R$-1.26 | Lucro percentual: 99.99%
# Iteração 419: | Lucro absoluto: R$-2.38 | Lucro percentual: 99.98%
# Iteração 420: | Lucro absoluto: R$-7.10 | Lucro percentual: 99.93%
# Iteração 421: | Lucro absoluto: R$13.92 | Lucro percentual: 100.14%
# Iteração 422: | Lucro absoluto: R$-9.91 | Lucro percentual: 99.90%
# Iteração 423: | Lucro absoluto: R$-10.42 | Lucro percentual: 99.90%
# Iteração 424: | Lucro absoluto: R$5.05 | Lucro percentual: 100.05%
# Iteração 425: | Lucro absoluto: R$8.72 | Lucro percentual: 100.09%
# Iteração 426: | Lucro absoluto: R$-13.89 | Lucro percentual: 99.86%
# Iteração 427: | Lucro absoluto: R$-3.91 | Lucro percentual: 99.96%
# Iteração 428: | Lucro absoluto: R$2.93 | Lucro percentual: 100.03%
# Iteração 429: | Lucro absoluto: R$6.06 | Lucro percentual: 100.06%
# Iteração 430: | Lucro absoluto: R$0.90 | Lucro percentual: 100.01%
# Iteração 431: | Lucro absoluto: R$7.09 | Lucro percentual: 100.07%
# Iteração 432: | Lucro absoluto: R$-2.61 | Lucro percentual: 99.97%
# Iteração 433: | Lucro absoluto: R$-2.45 | Lucro percentual: 99.98%
# Iteração 434: | Lucro absoluto: R$0.30 | Lucro percentual: 100.00%
# Iteração 435: | Lucro absoluto: R$-0.36 | Lucro percentual: 100.00%
# Iteração 436: | Lucro absoluto: R$1.62 | Lucro percentual: 100.02%
# Iteração 437: | Lucro absoluto: R$0.49 | Lucro percentual: 100.00%
# Iteração 438: | Lucro absoluto: R$-3.47 | Lucro percentual: 99.97%
# Iteração 439: | Lucro absoluto: R$-1.35 | Lucro percentual: 99.99%
# Iteração 440: | Lucro absoluto: R$-6.75 | Lucro percentual: 99.93%
# Iteração 441: | Lucro absoluto: R$-0.20 | Lucro percentual: 100.00%
# Iteração 442: | Lucro absoluto: R$2.62 | Lucro percentual: 100.03%
# Iteração 443: | Lucro absoluto: R$4.58 | Lucro percentual: 100.05%
# Iteração 444: | Lucro absoluto: R$2.19 | Lucro percentual: 100.02%
# Iteração 445: | Lucro absoluto: R$-6.15 | Lucro percentual: 99.94%
# Iteração 446: | Lucro absoluto: R$2.98 | Lucro percentual: 100.03%
# Iteração 447: | Lucro absoluto: R$-10.17 | Lucro percentual: 99.90%
# Iteração 448: | Lucro absoluto: R$-5.75 | Lucro percentual: 99.94%
# Iteração 449: | Lucro absoluto: R$3.75 | Lucro percentual: 100.04%
# Iteração 450: | Lucro absoluto: R$5.62 | Lucro percentual: 100.06%
# Iteração 451: | Lucro absoluto: R$10.15 | Lucro percentual: 100.10%
# Iteração 452: | Lucro absoluto: R$-13.41 | Lucro percentual: 99.87%
# Iteração 453: | Lucro absoluto: R$2.65 | Lucro percentual: 100.03%
# Iteração 454: | Lucro absoluto: R$1.02 | Lucro percentual: 100.01%
# Iteração 455: | Lucro absoluto: R$-6.39 | Lucro percentual: 99.94%
# Iteração 456: | Lucro absoluto: R$-5.95 | Lucro percentual: 99.94%
# Iteração 457: | Lucro absoluto: R$6.86 | Lucro percentual: 100.07%
# Iteração 458: | Lucro absoluto: R$5.45 | Lucro percentual: 100.05%
# Iteração 459: | Lucro absoluto: R$5.42 | Lucro percentual: 100.05%
# Iteração 460: | Lucro absoluto: R$-10.60 | Lucro percentual: 99.89%
# Iteração 461: | Lucro absoluto: R$-6.52 | Lucro percentual: 99.93%
# Iteração 462: | Lucro absoluto: R$-6.87 | Lucro percentual: 99.93%
# Iteração 463: | Lucro absoluto: R$0.95 | Lucro percentual: 100.01%
# Iteração 464: | Lucro absoluto: R$4.23 | Lucro percentual: 100.04%
# Iteração 465: | Lucro absoluto: R$4.60 | Lucro percentual: 100.05%
# Iteração 466: | Lucro absoluto: R$0.78 | Lucro percentual: 100.01%
# Iteração 467: | Lucro absoluto: R$-3.30 | Lucro percentual: 99.97%
# Iteração 468: | Lucro absoluto: R$-2.14 | Lucro percentual: 99.98%
# Iteração 469: | Lucro absoluto: R$1.51 | Lucro percentual: 100.02%
# Iteração 470: | Lucro absoluto: R$4.02 | Lucro percentual: 100.04%
# Iteração 471: | Lucro absoluto: R$-0.05 | Lucro percentual: 100.00%
# Iteração 472: | Lucro absoluto: R$-0.01 | Lucro percentual: 100.00%
# Iteração 473: | Lucro absoluto: R$2.56 | Lucro percentual: 100.03%
# Iteração 474: | Lucro absoluto: R$-19.32 | Lucro percentual: 99.81%
# Iteração 475: | Lucro absoluto: R$-1.17 | Lucro percentual: 99.99%
# Iteração 476: | Lucro absoluto: R$-5.79 | Lucro percentual: 99.94%
# Iteração 477: | Lucro absoluto: R$-4.68 | Lucro percentual: 99.95%
# Iteração 478: | Lucro absoluto: R$6.91 | Lucro percentual: 100.07%
# Iteração 479: | Lucro absoluto: R$3.05 | Lucro percentual: 100.03%
# Iteração 480: | Lucro absoluto: R$-4.05 | Lucro percentual: 99.96%
# Iteração 481: | Lucro absoluto: R$-2.01 | Lucro percentual: 99.98%
# Iteração 482: | Lucro absoluto: R$1.42 | Lucro percentual: 100.01%
# Iteração 483: | Lucro absoluto: R$-1.20 | Lucro percentual: 99.99%
# Iteração 484: | Lucro absoluto: R$-1.93 | Lucro percentual: 99.98%
# Iteração 485: | Lucro absoluto: R$1.98 | Lucro percentual: 100.02%
# Iteração 486: | Lucro absoluto: R$1.93 | Lucro percentual: 100.02%
# Iteração 487: | Lucro absoluto: R$-0.09 | Lucro percentual: 100.00%
# Iteração 488: | Lucro absoluto: R$0.90 | Lucro percentual: 100.01%
# Iteração 489: | Lucro absoluto: R$-3.35 | Lucro percentual: 99.97%
# Iteração 490: | Lucro absoluto: R$-4.07 | Lucro percentual: 99.96%
# Iteração 491: | Lucro absoluto: R$4.07 | Lucro percentual: 100.04%
# Iteração 492: | Lucro absoluto: R$-6.84 | Lucro percentual: 99.93%
# Iteração 493: | Lucro absoluto: R$6.73 | Lucro percentual: 100.07%
# Iteração 494: | Lucro absoluto: R$-4.37 | Lucro percentual: 99.96%
# Iteração 495: | Lucro absoluto: R$-7.55 | Lucro percentual: 99.92%
# Iteração 496: | Lucro absoluto: R$6.51 | Lucro percentual: 100.07%
# Iteração 497: | Lucro absoluto: R$1.28 | Lucro percentual: 100.01%
# Iteração 498: | Lucro absoluto: R$-19.41 | Lucro percentual: 99.81%
# Iteração 499: | Lucro absoluto: R$4.71 | Lucro percentual: 100.05%
# Iteração 500: | Lucro absoluto: R$5.52 | Lucro percentual: 100.06%
# Iteração 501: | Lucro absoluto: R$2.19 | Lucro percentual: 100.02%
# Iteração 502: | Lucro absoluto: R$4.81 | Lucro percentual: 100.05%
# Iteração 503: | Lucro absoluto: R$1.51 | Lucro percentual: 100.02%
# Iteração 504: | Lucro absoluto: R$0.72 | Lucro percentual: 100.01%
# Iteração 505: | Lucro absoluto: R$0.70 | Lucro percentual: 100.01%
# Iteração 506: | Lucro absoluto: R$-4.10 | Lucro percentual: 99.96%
# Iteração 507: | Lucro absoluto: R$1.03 | Lucro percentual: 100.01%
# Iteração 508: | Lucro absoluto: R$3.64 | Lucro percentual: 100.04%
# Iteração 509: | Lucro absoluto: R$-14.61 | Lucro percentual: 99.85%
# Iteração 510: | Lucro absoluto: R$-1.29 | Lucro percentual: 99.99%
# Iteração 511: | Lucro absoluto: R$-2.33 | Lucro percentual: 99.98%
# Iteração 512: | Lucro absoluto: R$-10.30 | Lucro percentual: 99.90%
# Iteração 513: | Lucro absoluto: R$-3.22 | Lucro percentual: 99.97%
# Iteração 514: | Lucro absoluto: R$0.98 | Lucro percentual: 100.01%
# Iteração 515: | Lucro absoluto: R$-0.18 | Lucro percentual: 100.00%
# Iteração 516: | Lucro absoluto: R$-4.50 | Lucro percentual: 99.95%
# Iteração 517: | Lucro absoluto: R$9.51 | Lucro percentual: 100.10%
# Iteração 518: | Lucro absoluto: R$0.37 | Lucro percentual: 100.00%
# Iteração 519: | Lucro absoluto: R$-15.67 | Lucro percentual: 99.84%
# Iteração 520: | Lucro absoluto: R$-0.47 | Lucro percentual: 100.00%
# Iteração 521: | Lucro absoluto: R$-3.39 | Lucro percentual: 99.97%
# Iteração 522: | Lucro absoluto: R$-2.83 | Lucro percentual: 99.97%
# Iteração 523: | Lucro absoluto: R$-10.84 | Lucro percentual: 99.89%
# Iteração 524: | Lucro absoluto: R$-1.33 | Lucro percentual: 99.99%
# Iteração 525: | Lucro absoluto: R$-11.19 | Lucro percentual: 99.89%
# Iteração 526: | Lucro absoluto: R$8.93 | Lucro percentual: 100.09%
# Iteração 527: | Lucro absoluto: R$0.50 | Lucro percentual: 100.00%
# Iteração 528: | Lucro absoluto: R$1.61 | Lucro percentual: 100.02%
# Iteração 529: | Lucro absoluto: R$1.37 | Lucro percentual: 100.01%
# Iteração 530: | Lucro absoluto: R$9.10 | Lucro percentual: 100.09%
# Iteração 531: | Lucro absoluto: R$0.55 | Lucro percentual: 100.01%
# Iteração 532: | Lucro absoluto: R$5.38 | Lucro percentual: 100.05%
# Iteração 533: | Lucro absoluto: R$9.74 | Lucro percentual: 100.10%
# Iteração 534: | Lucro absoluto: R$4.06 | Lucro percentual: 100.04%
# Iteração 535: | Lucro absoluto: R$-1.90 | Lucro percentual: 99.98%
# Iteração 536: | Lucro absoluto: R$-13.88 | Lucro percentual: 99.86%
# Iteração 537: | Lucro absoluto: R$12.23 | Lucro percentual: 100.12%
# Iteração 538: | Lucro absoluto: R$-0.47 | Lucro percentual: 100.00%
# Iteração 539: | Lucro absoluto: R$3.94 | Lucro percentual: 100.04%
# Iteração 540: | Lucro absoluto: R$-7.88 | Lucro percentual: 99.92%
# Iteração 541: | Lucro absoluto: R$-6.04 | Lucro percentual: 99.94%
# Iteração 542: | Lucro absoluto: R$-1.14 | Lucro percentual: 99.99%
# Iteração 543: | Lucro absoluto: R$9.36 | Lucro percentual: 100.09%
# Iteração 544: | Lucro absoluto: R$1.38 | Lucro percentual: 100.01%
# Iteração 545: | Lucro absoluto: R$-14.67 | Lucro percentual: 99.85%
# Iteração 546: | Lucro absoluto: R$-1.62 | Lucro percentual: 99.98%
# Iteração 547: | Lucro absoluto: R$-4.59 | Lucro percentual: 99.95%
# Iteração 548: | Lucro absoluto: R$-21.40 | Lucro percentual: 99.79%
# Iteração 549: | Lucro absoluto: R$-6.32 | Lucro percentual: 99.94%
# Iteração 550: | Lucro absoluto: R$-12.53 | Lucro percentual: 99.87%
# Iteração 551: | Lucro absoluto: R$-4.41 | Lucro percentual: 99.96%
# Iteração 552: | Lucro absoluto: R$5.50 | Lucro percentual: 100.05%
# Iteração 553: | Lucro absoluto: R$9.19 | Lucro percentual: 100.09%
# Iteração 554: | Lucro absoluto: R$-8.93 | Lucro percentual: 99.91%
# Iteração 555: | Lucro absoluto: R$2.11 | Lucro percentual: 100.02%
# Iteração 556: | Lucro absoluto: R$0.70 | Lucro percentual: 100.01%
# Iteração 557: | Lucro absoluto: R$-1.18 | Lucro percentual: 99.99%
# Iteração 558: | Lucro absoluto: R$-0.42 | Lucro percentual: 100.00%
# Iteração 559: | Lucro absoluto: R$9.70 | Lucro percentual: 100.10%
# Iteração 560: | Lucro absoluto: R$-0.23 | Lucro percentual: 100.00%
# Iteração 561: | Lucro absoluto: R$-9.83 | Lucro percentual: 99.90%
# Iteração 562: | Lucro absoluto: R$-3.09 | Lucro percentual: 99.97%
# Iteração 563: | Lucro absoluto: R$2.05 | Lucro percentual: 100.02%
# Iteração 564: | Lucro absoluto: R$-10.11 | Lucro percentual: 99.90%
# Iteração 565: | Lucro absoluto: R$3.52 | Lucro percentual: 100.04%
# Iteração 566: | Lucro absoluto: R$-12.11 | Lucro percentual: 99.88%
# Iteração 567: | Lucro absoluto: R$-5.70 | Lucro percentual: 99.94%
# Iteração 568: | Lucro absoluto: R$-7.95 | Lucro percentual: 99.92%
# Iteração 569: | Lucro absoluto: R$6.96 | Lucro percentual: 100.07%
# Iteração 570: | Lucro absoluto: R$-2.83 | Lucro percentual: 99.97%
# Iteração 571: | Lucro absoluto: R$-13.83 | Lucro percentual: 99.86%
# Iteração 572: | Lucro absoluto: R$0.77 | Lucro percentual: 100.01%
# Iteração 573: | Lucro absoluto: R$-8.23 | Lucro percentual: 99.92%
# Iteração 574: | Lucro absoluto: R$-0.23 | Lucro percentual: 100.00%
# Iteração 575: | Lucro absoluto: R$-0.25 | Lucro percentual: 100.00%
# Iteração 576: | Lucro absoluto: R$12.03 | Lucro percentual: 100.12%
# Iteração 577: | Lucro absoluto: R$6.98 | Lucro percentual: 100.07%
# Iteração 578: | Lucro absoluto: R$-5.37 | Lucro percentual: 99.95%
# Iteração 579: | Lucro absoluto: R$0.26 | Lucro percentual: 100.00%
# Iteração 580: | Lucro absoluto: R$8.02 | Lucro percentual: 100.08%
# Iteração 581: | Lucro absoluto: R$2.67 | Lucro percentual: 100.03%
# Iteração 582: | Lucro absoluto: R$-1.16 | Lucro percentual: 99.99%
# Iteração 583: | Lucro absoluto: R$3.14 | Lucro percentual: 100.03%
# Iteração 584: | Lucro absoluto: R$-4.81 | Lucro percentual: 99.95%
# Iteração 585: | Lucro absoluto: R$6.64 | Lucro percentual: 100.07%
# Iteração 586: | Lucro absoluto: R$-3.66 | Lucro percentual: 99.96%
# Iteração 587: | Lucro absoluto: R$-5.71 | Lucro percentual: 99.94%
# Iteração 588: | Lucro absoluto: R$1.46 | Lucro percentual: 100.01%
# Iteração 589: | Lucro absoluto: R$0.38 | Lucro percentual: 100.00%
# Iteração 590: | Lucro absoluto: R$-2.89 | Lucro percentual: 99.97%
# Iteração 591: | Lucro absoluto: R$4.09 | Lucro percentual: 100.04%
# Iteração 592: | Lucro absoluto: R$-2.91 | Lucro percentual: 99.97%
# Iteração 593: | Lucro absoluto: R$-1.53 | Lucro percentual: 99.98%
# Iteração 594: | Lucro absoluto: R$-8.19 | Lucro percentual: 99.92%
# Iteração 595: | Lucro absoluto: R$-0.61 | Lucro percentual: 99.99%
# Iteração 596: | Lucro absoluto: R$4.96 | Lucro percentual: 100.05%
# Iteração 597: | Lucro absoluto: R$-5.47 | Lucro percentual: 99.95%
# Iteração 598: | Lucro absoluto: R$-0.95 | Lucro percentual: 99.99%
# Iteração 599: | Lucro absoluto: R$3.58 | Lucro percentual: 100.04%
# Iteração 600: | Lucro absoluto: R$3.23 | Lucro percentual: 100.03%
# Iteração 601: | Lucro absoluto: R$11.13 | Lucro percentual: 100.11%
# Iteração 602: | Lucro absoluto: R$4.18 | Lucro percentual: 100.04%
# Iteração 603: | Lucro absoluto: R$2.79 | Lucro percentual: 100.03%
# Iteração 604: | Lucro absoluto: R$-1.18 | Lucro percentual: 99.99%
# Iteração 605: | Lucro absoluto: R$-4.57 | Lucro percentual: 99.95%
# Iteração 606: | Lucro absoluto: R$7.61 | Lucro percentual: 100.08%
# Iteração 607: | Lucro absoluto: R$4.28 | Lucro percentual: 100.04%
# Iteração 608: | Lucro absoluto: R$-4.25 | Lucro percentual: 99.96%
# Iteração 609: | Lucro absoluto: R$-15.69 | Lucro percentual: 99.84%
# Iteração 610: | Lucro absoluto: R$-1.59 | Lucro percentual: 99.98%
# Iteração 611: | Lucro absoluto: R$1.38 | Lucro percentual: 100.01%
# Iteração 612: | Lucro absoluto: R$2.22 | Lucro percentual: 100.02%
# Iteração 613: | Lucro absoluto: R$-7.66 | Lucro percentual: 99.92%
# Iteração 614: | Lucro absoluto: R$-6.95 | Lucro percentual: 99.93%
# Iteração 615: | Lucro absoluto: R$-1.19 | Lucro percentual: 99.99%
# Iteração 616: | Lucro absoluto: R$6.52 | Lucro percentual: 100.07%
# Iteração 617: | Lucro absoluto: R$6.53 | Lucro percentual: 100.07%
# Iteração 618: | Lucro absoluto: R$10.72 | Lucro percentual: 100.11%
# Iteração 619: | Lucro absoluto: R$-18.26 | Lucro percentual: 99.82%
# Iteração 620: | Lucro absoluto: R$4.14 | Lucro percentual: 100.04%
# Iteração 621: | Lucro absoluto: R$7.16 | Lucro percentual: 100.07%
# Iteração 622: | Lucro absoluto: R$-3.67 | Lucro percentual: 99.96%
# Iteração 623: | Lucro absoluto: R$-6.28 | Lucro percentual: 99.94%
# Iteração 624: | Lucro absoluto: R$-6.38 | Lucro percentual: 99.94%
# Iteração 625: | Lucro absoluto: R$-2.61 | Lucro percentual: 99.97%
# Iteração 626: | Lucro absoluto: R$0.86 | Lucro percentual: 100.01%
# Iteração 627: | Lucro absoluto: R$-15.57 | Lucro percentual: 99.84%
# Iteração 628: | Lucro absoluto: R$1.75 | Lucro percentual: 100.02%
# Iteração 629: | Lucro absoluto: R$4.22 | Lucro percentual: 100.04%
# Iteração 630: | Lucro absoluto: R$-4.20 | Lucro percentual: 99.96%
# Iteração 631: | Lucro absoluto: R$5.64 | Lucro percentual: 100.06%
# Iteração 632: | Lucro absoluto: R$-2.74 | Lucro percentual: 99.97%
# Iteração 633: | Lucro absoluto: R$4.48 | Lucro percentual: 100.04%
# Iteração 634: | Lucro absoluto: R$-2.75 | Lucro percentual: 99.97%
# Iteração 635: | Lucro absoluto: R$-5.97 | Lucro percentual: 99.94%
# Iteração 636: | Lucro absoluto: R$1.32 | Lucro percentual: 100.01%
# Iteração 637: | Lucro absoluto: R$-2.49 | Lucro percentual: 99.98%
# Iteração 638: | Lucro absoluto: R$7.97 | Lucro percentual: 100.08%
# Iteração 639: | Lucro absoluto: R$3.91 | Lucro percentual: 100.04%
# Iteração 640: | Lucro absoluto: R$-2.73 | Lucro percentual: 99.97%
# Iteração 641: | Lucro absoluto: R$-3.98 | Lucro percentual: 99.96%
# Iteração 642: | Lucro absoluto: R$8.56 | Lucro percentual: 100.09%
# Iteração 643: | Lucro absoluto: R$4.76 | Lucro percentual: 100.05%
# Iteração 644: | Lucro absoluto: R$1.65 | Lucro percentual: 100.02%
# Iteração 645: | Lucro absoluto: R$3.77 | Lucro percentual: 100.04%
# Iteração 646: | Lucro absoluto: R$-6.61 | Lucro percentual: 99.93%
# Iteração 647: | Lucro absoluto: R$-5.53 | Lucro percentual: 99.94%
# Iteração 648: | Lucro absoluto: R$-1.76 | Lucro percentual: 99.98%
# Iteração 649: | Lucro absoluto: R$2.30 | Lucro percentual: 100.02%
# Iteração 650: | Lucro absoluto: R$4.57 | Lucro percentual: 100.05%
# Iteração 651: | Lucro absoluto: R$-12.21 | Lucro percentual: 99.88%
# Iteração 652: | Lucro absoluto: R$1.81 | Lucro percentual: 100.02%
# Iteração 653: | Lucro absoluto: R$-4.59 | Lucro percentual: 99.95%
# Iteração 654: | Lucro absoluto: R$11.39 | Lucro percentual: 100.11%
# Iteração 655: | Lucro absoluto: R$-2.25 | Lucro percentual: 99.98%
# Iteração 656: | Lucro absoluto: R$0.98 | Lucro percentual: 100.01%
# Iteração 657: | Lucro absoluto: R$-4.35 | Lucro percentual: 99.96%
# Iteração 658: | Lucro absoluto: R$-11.70 | Lucro percentual: 99.88%
# Iteração 659: | Lucro absoluto: R$6.21 | Lucro percentual: 100.06%
# Iteração 660: | Lucro absoluto: R$-3.90 | Lucro percentual: 99.96%
# Iteração 661: | Lucro absoluto: R$1.97 | Lucro percentual: 100.02%
# Iteração 662: | Lucro absoluto: R$-2.77 | Lucro percentual: 99.97%
# Iteração 663: | Lucro absoluto: R$0.73 | Lucro percentual: 100.01%
# Iteração 664: | Lucro absoluto: R$-3.00 | Lucro percentual: 99.97%
# Iteração 665: | Lucro absoluto: R$-5.55 | Lucro percentual: 99.94%
# Iteração 666: | Lucro absoluto: R$4.93 | Lucro percentual: 100.05%
# Iteração 667: | Lucro absoluto: R$0.91 | Lucro percentual: 100.01%
# Iteração 668: | Lucro absoluto: R$-3.21 | Lucro percentual: 99.97%
# Iteração 669: | Lucro absoluto: R$2.10 | Lucro percentual: 100.02%
# Iteração 670: | Lucro absoluto: R$3.26 | Lucro percentual: 100.03%
# Iteração 671: | Lucro absoluto: R$0.42 | Lucro percentual: 100.00%
# Iteração 672: | Lucro absoluto: R$-0.50 | Lucro percentual: 100.00%
# Iteração 673: | Lucro absoluto: R$-4.29 | Lucro percentual: 99.96%
# Iteração 674: | Lucro absoluto: R$-3.39 | Lucro percentual: 99.97%
# Iteração 675: | Lucro absoluto: R$8.35 | Lucro percentual: 100.08%
# Iteração 676: | Lucro absoluto: R$5.56 | Lucro percentual: 100.06%
# Iteração 677: | Lucro absoluto: R$1.19 | Lucro percentual: 100.01%
# Iteração 678: | Lucro absoluto: R$-4.23 | Lucro percentual: 99.96%
# Iteração 679: | Lucro absoluto: R$8.64 | Lucro percentual: 100.09%
# Iteração 680: | Lucro absoluto: R$9.82 | Lucro percentual: 100.10%
# Iteração 681: | Lucro absoluto: R$3.75 | Lucro percentual: 100.04%
# Iteração 682: | Lucro absoluto: R$5.16 | Lucro percentual: 100.05%
# Iteração 683: | Lucro absoluto: R$-5.51 | Lucro percentual: 99.94%
# Iteração 684: | Lucro absoluto: R$1.76 | Lucro percentual: 100.02%
# Iteração 685: | Lucro absoluto: R$-12.23 | Lucro percentual: 99.88%
# Iteração 686: | Lucro absoluto: R$0.05 | Lucro percentual: 100.00%
# Iteração 687: | Lucro absoluto: R$1.24 | Lucro percentual: 100.01%
# Iteração 688: | Lucro absoluto: R$-11.36 | Lucro percentual: 99.89%
# Iteração 689: | Lucro absoluto: R$2.63 | Lucro percentual: 100.03%
# Iteração 690: | Lucro absoluto: R$2.17 | Lucro percentual: 100.02%
# Iteração 691: | Lucro absoluto: R$9.77 | Lucro percentual: 100.10%
# Iteração 692: | Lucro absoluto: R$-2.05 | Lucro percentual: 99.98%
# Iteração 693: | Lucro absoluto: R$4.59 | Lucro percentual: 100.05%
# Iteração 694: | Lucro absoluto: R$9.49 | Lucro percentual: 100.09%
# Iteração 695: | Lucro absoluto: R$-0.37 | Lucro percentual: 100.00%
# Iteração 696: | Lucro absoluto: R$2.83 | Lucro percentual: 100.03%
# Iteração 697: | Lucro absoluto: R$-8.08 | Lucro percentual: 99.92%
# Iteração 698: | Lucro absoluto: R$-7.39 | Lucro percentual: 99.93%
# Iteração 699: | Lucro absoluto: R$-1.74 | Lucro percentual: 99.98%
# Iteração 700: | Lucro absoluto: R$4.07 | Lucro percentual: 100.04%
# Iteração 701: | Lucro absoluto: R$-0.93 | Lucro percentual: 99.99%
# Iteração 702: | Lucro absoluto: R$8.27 | Lucro percentual: 100.08%
# Iteração 703: | Lucro absoluto: R$4.03 | Lucro percentual: 100.04%
# Iteração 704: | Lucro absoluto: R$-6.20 | Lucro percentual: 99.94%
# Iteração 705: | Lucro absoluto: R$0.60 | Lucro percentual: 100.01%
# Iteração 706: | Lucro absoluto: R$2.89 | Lucro percentual: 100.03%
# Iteração 707: | Lucro absoluto: R$-4.17 | Lucro percentual: 99.96%
# Iteração 708: | Lucro absoluto: R$-3.05 | Lucro percentual: 99.97%
# Iteração 709: | Lucro absoluto: R$-3.46 | Lucro percentual: 99.97%
# Iteração 710: | Lucro absoluto: R$1.65 | Lucro percentual: 100.02%
# Iteração 711: | Lucro absoluto: R$-0.59 | Lucro percentual: 99.99%
# Iteração 712: | Lucro absoluto: R$0.48 | Lucro percentual: 100.00%
# Iteração 713: | Lucro absoluto: R$2.65 | Lucro percentual: 100.03%
# Iteração 714: | Lucro absoluto: R$7.33 | Lucro percentual: 100.07%
# Iteração 715: | Lucro absoluto: R$-4.02 | Lucro percentual: 99.96%
# ...
# Iteração 764: | Lucro absoluto: R$3.25 | Lucro percentual: 100.03%
# Iteração 765: | Lucro absoluto: R$9.60 | Lucro percentual: 100.10%
# Iteração 766: | Lucro absoluto: R$-21.15 | Lucro percentual: 99.79%
# Iteração 767: | Lucro absoluto: R$-0.25 | Lucro percentual: 100.00%
# Iteração 768: | Lucro absoluto: R$0.71 | Lucro percentual: 100.01%
# Iteração 769: | Lucro absoluto: R$-1.36 | Lucro percentual: 99.99%
# Iteração 770: | Lucro absoluto: R$8.05 | Lucro percentual: 100.08%
# Iteração 771: | Lucro absoluto: R$-3.13 | Lucro percentual: 99.97%
# Iteração 772: | Lucro absoluto: R$-0.23 | Lucro percentual: 100.00%
# Iteração 773: | Lucro absoluto: R$2.55 | Lucro percentual: 100.03%
# Iteração 774: | Lucro absoluto: R$7.76 | Lucro percentual: 100.08%
# Iteração 775: | Lucro absoluto: R$-4.63 | Lucro percentual: 99.95%
# Iteração 776: | Lucro absoluto: R$-12.18 | Lucro percentual: 99.88%
# Iteração 777: | Lucro absoluto: R$4.60 | Lucro percentual: 100.05%
# Iteração 778: | Lucro absoluto: R$4.80 | Lucro percentual: 100.05%
# Iteração 779: | Lucro absoluto: R$3.46 | Lucro percentual: 100.03%
# Iteração 780: | Lucro absoluto: R$-7.40 | Lucro percentual: 99.93%
# Iteração 781: | Lucro absoluto: R$-1.38 | Lucro percentual: 99.99%
# Iteração 782: | Lucro absoluto: R$-13.17 | Lucro percentual: 99.87%
# Iteração 783: | Lucro absoluto: R$-6.73 | Lucro percentual: 99.93%
# Iteração 784: | Lucro absoluto: R$12.28 | Lucro percentual: 100.12%
# Iteração 785: | Lucro absoluto: R$-11.71 | Lucro percentual: 99.88%
# Iteração 786: | Lucro absoluto: R$0.31 | Lucro percentual: 100.00%
# Iteração 787: | Lucro absoluto: R$-7.36 | Lucro percentual: 99.93%
# Iteração 788: | Lucro absoluto: R$3.18 | Lucro percentual: 100.03%
# Iteração 789: | Lucro absoluto: R$4.34 | Lucro percentual: 100.04%
# Iteração 790: | Lucro absoluto: R$-2.82 | Lucro percentual: 99.97%
# Iteração 791: | Lucro absoluto: R$-1.04 | Lucro percentual: 99.99%
# Iteração 792: | Lucro absoluto: R$-4.90 | Lucro percentual: 99.95%
# Iteração 793: | Lucro absoluto: R$-1.02 | Lucro percentual: 99.99%
# Iteração 794: | Lucro absoluto: R$-6.66 | Lucro percentual: 99.93%
# Iteração 795: | Lucro absoluto: R$0.40 | Lucro percentual: 100.00%
# Iteração 796: | Lucro absoluto: R$-2.78 | Lucro percentual: 99.97%
# Iteração 797: | Lucro absoluto: R$1.47 | Lucro percentual: 100.01%
# Iteração 798: | Lucro absoluto: R$-19.59 | Lucro percentual: 99.80%
# Iteração 799: | Lucro absoluto: R$9.14 | Lucro percentual: 100.09%
# Iteração 800: | Lucro absoluto: R$9.79 | Lucro percentual: 100.10%
# Iteração 801: | Lucro absoluto: R$-5.82 | Lucro percentual: 99.94%
# Iteração 802: | Lucro absoluto: R$8.95 | Lucro percentual: 100.09%
# Iteração 803: | Lucro absoluto: R$-2.35 | Lucro percentual: 99.98%
# Iteração 804: | Lucro absoluto: R$3.25 | Lucro percentual: 100.03%
# Iteração 805: | Lucro absoluto: R$1.46 | Lucro percentual: 100.01%
# Iteração 806: | Lucro absoluto: R$10.26 | Lucro percentual: 100.10%
# Iteração 807: | Lucro absoluto: R$-10.67 | Lucro percentual: 99.89%
# Iteração 808: | Lucro absoluto: R$-4.55 | Lucro percentual: 99.95%
# Iteração 809: | Lucro absoluto: R$-2.25 | Lucro percentual: 99.98%
# Iteração 810: | Lucro absoluto: R$-7.92 | Lucro percentual: 99.92%
# Iteração 811: | Lucro absoluto: R$6.75 | Lucro percentual: 100.07%
# Iteração 812: | Lucro absoluto: R$0.31 | Lucro percentual: 100.00%
# Iteração 813: | Lucro absoluto: R$4.73 | Lucro percentual: 100.05%
# Iteração 814: | Lucro absoluto: R$-6.10 | Lucro percentual: 99.94%
# Iteração 815: | Lucro absoluto: R$-2.87 | Lucro percentual: 99.97%
# Iteração 816: | Lucro absoluto: R$0.92 | Lucro percentual: 100.01%
# Iteração 817: | Lucro absoluto: R$-11.76 | Lucro percentual: 99.88%
# Iteração 818: | Lucro absoluto: R$-7.90 | Lucro percentual: 99.92%
# Iteração 819: | Lucro absoluto: R$-5.45 | Lucro percentual: 99.95%
# Iteração 820: | Lucro absoluto: R$5.41 | Lucro percentual: 100.05%
# Iteração 821: | Lucro absoluto: R$-0.72 | Lucro percentual: 99.99%
# Iteração 822: | Lucro absoluto: R$3.15 | Lucro percentual: 100.03%
# Iteração 823: | Lucro absoluto: R$0.12 | Lucro percentual: 100.00%
# Iteração 824: | Lucro absoluto: R$-0.51 | Lucro percentual: 99.99%
# Iteração 825: | Lucro absoluto: R$-4.14 | Lucro percentual: 99.96%
# Iteração 826: | Lucro absoluto: R$-13.81 | Lucro percentual: 99.86%
# Iteração 827: | Lucro absoluto: R$0.57 | Lucro percentual: 100.01%
# Iteração 828: | Lucro absoluto: R$-0.87 | Lucro percentual: 99.99%
# Iteração 829: | Lucro absoluto: R$-8.55 | Lucro percentual: 99.91%
# Iteração 830: | Lucro absoluto: R$-1.94 | Lucro percentual: 99.98%
# Iteração 831: | Lucro absoluto: R$6.02 | Lucro percentual: 100.06%
# Iteração 832: | Lucro absoluto: R$4.35 | Lucro percentual: 100.04%
# Iteração 833: | Lucro absoluto: R$-27.92 | Lucro percentual: 99.72%
# Iteração 834: | Lucro absoluto: R$2.77 | Lucro percentual: 100.03%
# Iteração 835: | Lucro absoluto: R$2.29 | Lucro percentual: 100.02%
# Iteração 836: | Lucro absoluto: R$-1.07 | Lucro percentual: 99.99%
# Iteração 837: | Lucro absoluto: R$2.30 | Lucro percentual: 100.02%
# Iteração 838: | Lucro absoluto: R$14.19 | Lucro percentual: 100.14%
# Iteração 839: | Lucro absoluto: R$-13.10 | Lucro percentual: 99.87%
# Iteração 840: | Lucro absoluto: R$4.12 | Lucro percentual: 100.04%
# Iteração 841: | Lucro absoluto: R$-11.70 | Lucro percentual: 99.88%
# Iteração 842: | Lucro absoluto: R$-5.81 | Lucro percentual: 99.94%
# Iteração 843: | Lucro absoluto: R$1.41 | Lucro percentual: 100.01%
# Iteração 844: | Lucro absoluto: R$1.19 | Lucro percentual: 100.01%
# Iteração 845: | Lucro absoluto: R$-0.92 | Lucro percentual: 99.99%
# Iteração 846: | Lucro absoluto: R$0.52 | Lucro percentual: 100.01%
# Iteração 847: | Lucro absoluto: R$1.17 | Lucro percentual: 100.01%
# Iteração 848: | Lucro absoluto: R$5.72 | Lucro percentual: 100.06%
# Iteração 849: | Lucro absoluto: R$0.01 | Lucro percentual: 100.00%
# Iteração 850: | Lucro absoluto: R$-6.08 | Lucro percentual: 99.94%
# Iteração 851: | Lucro absoluto: R$-2.95 | Lucro percentual: 99.97%
# Iteração 852: | Lucro absoluto: R$6.41 | Lucro percentual: 100.06%
# Iteração 853: | Lucro absoluto: R$0.03 | Lucro percentual: 100.00%
# Iteração 854: | Lucro absoluto: R$8.96 | Lucro percentual: 100.09%
# Iteração 855: | Lucro absoluto: R$-9.18 | Lucro percentual: 99.91%
# Iteração 856: | Lucro absoluto: R$-3.14 | Lucro percentual: 99.97%
# Iteração 857: | Lucro absoluto: R$6.74 | Lucro percentual: 100.07%
# Iteração 858: | Lucro absoluto: R$-2.48 | Lucro percentual: 99.98%
# Iteração 859: | Lucro absoluto: R$2.56 | Lucro percentual: 100.03%
# Iteração 860: | Lucro absoluto: R$11.20 | Lucro percentual: 100.11%
# Iteração 861: | Lucro absoluto: R$-2.32 | Lucro percentual: 99.98%
# Iteração 862: | Lucro absoluto: R$4.31 | Lucro percentual: 100.04%
# Iteração 863: | Lucro absoluto: R$0.57 | Lucro percentual: 100.01%
# Iteração 864: | Lucro absoluto: R$1.80 | Lucro percentual: 100.02%
# Iteração 865: | Lucro absoluto: R$-3.95 | Lucro percentual: 99.96%
# Iteração 866: | Lucro absoluto: R$-8.75 | Lucro percentual: 99.91%
# Iteração 867: | Lucro absoluto: R$-2.54 | Lucro percentual: 99.97%
# Iteração 868: | Lucro absoluto: R$-2.95 | Lucro percentual: 99.97%
# Iteração 869: | Lucro absoluto: R$1.39 | Lucro percentual: 100.01%
# Iteração 870: | Lucro absoluto: R$-0.91 | Lucro percentual: 99.99%
# Iteração 871: | Lucro absoluto: R$6.99 | Lucro percentual: 100.07%
# Iteração 872: | Lucro absoluto: R$-5.23 | Lucro percentual: 99.95%
# Iteração 873: | Lucro absoluto: R$1.92 | Lucro percentual: 100.02%
# Iteração 874: | Lucro absoluto: R$10.28 | Lucro percentual: 100.10%
# Iteração 875: | Lucro absoluto: R$8.27 | Lucro percentual: 100.08%
# Iteração 876: | Lucro absoluto: R$1.28 | Lucro percentual: 100.01%
# Iteração 877: | Lucro absoluto: R$10.38 | Lucro percentual: 100.10%
# Iteração 878: | Lucro absoluto: R$-3.30 | Lucro percentual: 99.97%
# Iteração 879: | Lucro absoluto: R$-8.03 | Lucro percentual: 99.92%
# Iteração 880: | Lucro absoluto: R$-6.55 | Lucro percentual: 99.93%
# Iteração 881: | Lucro absoluto: R$6.63 | Lucro percentual: 100.07%
# Iteração 882: | Lucro absoluto: R$-1.59 | Lucro percentual: 99.98%
# Iteração 883: | Lucro absoluto: R$-8.08 | Lucro percentual: 99.92%
# Iteração 884: | Lucro absoluto: R$-2.70 | Lucro percentual: 99.97%
# Iteração 885: | Lucro absoluto: R$-13.17 | Lucro percentual: 99.87%
# Iteração 886: | Lucro absoluto: R$13.22 | Lucro percentual: 100.13%
# Iteração 887: | Lucro absoluto: R$4.24 | Lucro percentual: 100.04%
# Iteração 888: | Lucro absoluto: R$-2.04 | Lucro percentual: 99.98%
# Iteração 889: | Lucro absoluto: R$2.93 | Lucro percentual: 100.03%
# Iteração 890: | Lucro absoluto: R$11.35 | Lucro percentual: 100.11%
# Iteração 891: | Lucro absoluto: R$4.17 | Lucro percentual: 100.04%
# Iteração 892: | Lucro absoluto: R$-7.77 | Lucro percentual: 99.92%
# Iteração 893: | Lucro absoluto: R$2.16 | Lucro percentual: 100.02%
# Iteração 894: | Lucro absoluto: R$-1.98 | Lucro percentual: 99.98%
# Iteração 895: | Lucro absoluto: R$-0.00 | Lucro percentual: 100.00%
# Iteração 896: | Lucro absoluto: R$-1.97 | Lucro percentual: 99.98%
# Iteração 897: | Lucro absoluto: R$3.99 | Lucro percentual: 100.04%
# Iteração 898: | Lucro absoluto: R$-2.55 | Lucro percentual: 99.97%
# Iteração 899: | Lucro absoluto: R$-12.48 | Lucro percentual: 99.88%
# Iteração 900: | Lucro absoluto: R$-3.60 | Lucro percentual: 99.96%
# Iteração 901: | Lucro absoluto: R$0.16 | Lucro percentual: 100.00%
# Iteração 902: | Lucro absoluto: R$4.71 | Lucro percentual: 100.05%
# Iteração 903: | Lucro absoluto: R$1.66 | Lucro percentual: 100.02%
# Iteração 904: | Lucro absoluto: R$-3.77 | Lucro percentual: 99.96%
# Iteração 905: | Lucro absoluto: R$-6.83 | Lucro percentual: 99.93%
# Iteração 906: | Lucro absoluto: R$11.38 | Lucro percentual: 100.11%
# Iteração 907: | Lucro absoluto: R$2.43 | Lucro percentual: 100.02%
# Iteração 908: | Lucro absoluto: R$3.25 | Lucro percentual: 100.03%
# Iteração 909: | Lucro absoluto: R$0.02 | Lucro percentual: 100.00%
# Iteração 910: | Lucro absoluto: R$0.75 | Lucro percentual: 100.01%
# Iteração 911: | Lucro absoluto: R$-4.26 | Lucro percentual: 99.96%
# Iteração 912: | Lucro absoluto: R$-14.83 | Lucro percentual: 99.85%
# Iteração 913: | Lucro absoluto: R$-10.79 | Lucro percentual: 99.89%
# Iteração 914: | Lucro absoluto: R$2.08 | Lucro percentual: 100.02%
# Iteração 915: | Lucro absoluto: R$-1.35 | Lucro percentual: 99.99%
# Iteração 916: | Lucro absoluto: R$-5.77 | Lucro percentual: 99.94%
# Iteração 917: | Lucro absoluto: R$4.87 | Lucro percentual: 100.05%
# Iteração 918: | Lucro absoluto: R$1.50 | Lucro percentual: 100.01%
# Iteração 919: | Lucro absoluto: R$6.42 | Lucro percentual: 100.06%
# Iteração 920: | Lucro absoluto: R$-6.66 | Lucro percentual: 99.93%
# Iteração 921: | Lucro absoluto: R$-11.47 | Lucro percentual: 99.89%
# Iteração 922: | Lucro absoluto: R$0.17 | Lucro percentual: 100.00%
# Iteração 923: | Lucro absoluto: R$6.87 | Lucro percentual: 100.07%
# Iteração 924: | Lucro absoluto: R$-2.61 | Lucro percentual: 99.97%
# Iteração 925: | Lucro absoluto: R$2.15 | Lucro percentual: 100.02%
# Iteração 926: | Lucro absoluto: R$6.29 | Lucro percentual: 100.06%
# Iteração 927: | Lucro absoluto: R$1.76 | Lucro percentual: 100.02%
# Iteração 928: | Lucro absoluto: R$5.65 | Lucro percentual: 100.06%
# Iteração 929: | Lucro absoluto: R$-32.05 | Lucro percentual: 99.68%
# Iteração 930: | Lucro absoluto: R$4.20 | Lucro percentual: 100.04%
# Iteração 931: | Lucro absoluto: R$3.51 | Lucro percentual: 100.04%
# Iteração 932: | Lucro absoluto: R$1.83 | Lucro percentual: 100.02%
# Iteração 933: | Lucro absoluto: R$2.94 | Lucro percentual: 100.03%
# Iteração 934: | Lucro absoluto: R$-1.72 | Lucro percentual: 99.98%
# Iteração 935: | Lucro absoluto: R$2.11 | Lucro percentual: 100.02%
# Iteração 936: | Lucro absoluto: R$4.99 | Lucro percentual: 100.05%
# Iteração 937: | Lucro absoluto: R$0.99 | Lucro percentual: 100.01%
# Iteração 938: | Lucro absoluto: R$2.15 | Lucro percentual: 100.02%
# Iteração 939: | Lucro absoluto: R$1.65 | Lucro percentual: 100.02%
# Iteração 940: | Lucro absoluto: R$2.20 | Lucro percentual: 100.02%
# Iteração 941: | Lucro absoluto: R$2.70 | Lucro percentual: 100.03%
# Iteração 942: | Lucro absoluto: R$-10.26 | Lucro percentual: 99.90%
# Iteração 943: | Lucro absoluto: R$4.78 | Lucro percentual: 100.05%
# Iteração 944: | Lucro absoluto: R$-16.74 | Lucro percentual: 99.83%
# Iteração 945: | Lucro absoluto: R$-0.83 | Lucro percentual: 99.99%
# Iteração 946: | Lucro absoluto: R$-5.20 | Lucro percentual: 99.95%
# Iteração 947: | Lucro absoluto: R$-32.90 | Lucro percentual: 99.67%
# Iteração 948: | Lucro absoluto: R$4.50 | Lucro percentual: 100.04%
# Iteração 949: | Lucro absoluto: R$-1.32 | Lucro percentual: 99.99%
# Iteração 950: | Lucro absoluto: R$6.61 | Lucro percentual: 100.07%
# Iteração 951: | Lucro absoluto: R$4.61 | Lucro percentual: 100.05%
# Iteração 952: | Lucro absoluto: R$-6.17 | Lucro percentual: 99.94%
# Iteração 953: | Lucro absoluto: R$1.80 | Lucro percentual: 100.02%
# Iteração 954: | Lucro absoluto: R$-2.01 | Lucro percentual: 99.98%
# Iteração 955: | Lucro absoluto: R$1.59 | Lucro percentual: 100.02%
# Iteração 956: | Lucro absoluto: R$-9.77 | Lucro percentual: 99.90%
# Iteração 957: | Lucro absoluto: R$7.02 | Lucro percentual: 100.07%
# Iteração 958: | Lucro absoluto: R$-6.81 | Lucro percentual: 99.93%
# Iteração 959: | Lucro absoluto: R$10.52 | Lucro percentual: 100.11%
# Iteração 960: | Lucro absoluto: R$-0.21 | Lucro percentual: 100.00%
# Iteração 961: | Lucro absoluto: R$0.32 | Lucro percentual: 100.00%
# Iteração 962: | Lucro absoluto: R$-6.61 | Lucro percentual: 99.93%
# Iteração 963: | Lucro absoluto: R$0.99 | Lucro percentual: 100.01%
# Iteração 964: | Lucro absoluto: R$-4.64 | Lucro percentual: 99.95%
# Iteração 965: | Lucro absoluto: R$1.00 | Lucro percentual: 100.01%
# Iteração 966: | Lucro absoluto: R$-12.69 | Lucro percentual: 99.87%
# Iteração 967: | Lucro absoluto: R$-12.77 | Lucro percentual: 99.87%
# Iteração 968: | Lucro absoluto: R$3.57 | Lucro percentual: 100.04%
# Iteração 969: | Lucro absoluto: R$3.79 | Lucro percentual: 100.04%
# Iteração 970: | Lucro absoluto: R$5.46 | Lucro percentual: 100.05%
# Iteração 971: | Lucro absoluto: R$1.43 | Lucro percentual: 100.01%
# Iteração 972: | Lucro absoluto: R$3.05 | Lucro percentual: 100.03%
# Iteração 973: | Lucro absoluto: R$-1.03 | Lucro percentual: 99.99%
# Iteração 974: | Lucro absoluto: R$3.59 | Lucro percentual: 100.04%
# Iteração 975: | Lucro absoluto: R$0.56 | Lucro percentual: 100.01%
# Iteração 976: | Lucro absoluto: R$5.35 | Lucro percentual: 100.05%
# Iteração 977: | Lucro absoluto: R$1.59 | Lucro percentual: 100.02%
# Iteração 978: | Lucro absoluto: R$2.80 | Lucro percentual: 100.03%
# Iteração 979: | Lucro absoluto: R$-3.21 | Lucro percentual: 99.97%
# Iteração 980: | Lucro absoluto: R$12.94 | Lucro percentual: 100.13%
# Iteração 981: | Lucro absoluto: R$3.77 | Lucro percentual: 100.04%
# Iteração 982: | Lucro absoluto: R$-0.71 | Lucro percentual: 99.99%
# Iteração 983: | Lucro absoluto: R$0.11 | Lucro percentual: 100.00%
# Iteração 984: | Lucro absoluto: R$-11.49 | Lucro percentual: 99.89%
# Iteração 985: | Lucro absoluto: R$-10.47 | Lucro percentual: 99.90%
# Iteração 986: | Lucro absoluto: R$1.16 | Lucro percentual: 100.01%
# Iteração 987: | Lucro absoluto: R$0.73 | Lucro percentual: 100.01%
# Iteração 988: | Lucro absoluto: R$-8.46 | Lucro percentual: 99.92%
# Iteração 989: | Lucro absoluto: R$-0.83 | Lucro percentual: 99.99%
# Iteração 990: | Lucro absoluto: R$-2.78 | Lucro percentual: 99.97%
# Iteração 991: | Lucro absoluto: R$1.25 | Lucro percentual: 100.01%
# Iteração 992: | Lucro absoluto: R$7.77 | Lucro percentual: 100.08%
# Iteração 993: | Lucro absoluto: R$4.83 | Lucro percentual: 100.05%
# Iteração 994: | Lucro absoluto: R$-4.25 | Lucro percentual: 99.96%
# Iteração 995: | Lucro absoluto: R$-15.38 | Lucro percentual: 99.85%
# Iteração 996: | Lucro absoluto: R$-4.68 | Lucro percentual: 99.95%
# Iteração 997: | Lucro absoluto: R$-6.44 | Lucro percentual: 99.94%
# Iteração 998: | Lucro absoluto: R$-0.80 | Lucro percentual: 99.99%
# Iteração 999: | Lucro absoluto: R$8.95 | Lucro percentual: 100.09%
# Iteração 1000: | Lucro absoluto: R$5.05 | Lucro percentual: 100.05%
# Lucro final em valor: R$ 1.17
# Lucro final em percentual: 100.01%
